# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive

drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
root_path = 'gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/'
# /content/gdrive/MyDrive/Upgrad_deeplearning_Assignment

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path(root_path+"Train")
data_dir_test = pathlib.Path(root_path+'Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir_train,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset="training",
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir_train,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset="validation",
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
### your code goes here, you can use training or validation data to visualize

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %% [markdown]
# ## **Model M1**

# %%
### Your code goes here

num_classes = 9

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255,input_shape = (img_height,img_width,3)),
  tf.keras.layers.Conv2D(16, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 89, 89, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 20, 20, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  dense_3 (Dense)             (None, 128)               3276928
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,318,185
# Trainable params: 3,318,185
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 15s 74ms/step - loss: 2.0215 - accuracy: 0.2321 - val_loss: 1.9114 - val_accuracy: 0.3356
# Epoch 2/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.7390 - accuracy: 0.3817 - val_loss: 1.6813 - val_accuracy: 0.4116
# Epoch 3/20
# 56/56 [==============================] - 2s 29ms/step - loss: 1.6479 - accuracy: 0.4007 - val_loss: 1.5302 - val_accuracy: 0.4743
# Epoch 4/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.4742 - accuracy: 0.4754 - val_loss: 1.4686 - val_accuracy: 0.5011
# Epoch 5/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.4391 - accuracy: 0.4978 - val_loss: 1.3873 - val_accuracy: 0.5280
# Epoch 6/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.3840 - accuracy: 0.5206 - val_loss: 1.4071 - val_accuracy: 0.5280
# Epoch 7/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.2771 - accuracy: 0.5485 - val_loss: 1.3343 - val_accuracy: 0.5347
# Epoch 8/20
# 56/56 [==============================] - 2s 29ms/step - loss: 1.2176 - accuracy: 0.5725 - val_loss: 1.3398 - val_accuracy: 0.5324
# Epoch 9/20
# 56/56 [==============================] - 2s 31ms/step - loss: 1.1417 - accuracy: 0.5882 - val_loss: 1.4062 - val_accuracy: 0.5347
# Epoch 10/20
# 56/56 [==============================] - 2s 29ms/step - loss: 1.1503 - accuracy: 0.5893 - val_loss: 1.3494 - val_accuracy: 0.5459
# Epoch 11/20
# 56/56 [==============================] - 2s 29ms/step - loss: 1.0403 - accuracy: 0.6289 - val_loss: 1.3513 - val_accuracy: 0.5548
# Epoch 12/20
# 56/56 [==============================] - 1s 24ms/step - loss: 0.9224 - accuracy: 0.6657 - val_loss: 1.4756 - val_accuracy: 0.5526
# Epoch 13/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.8448 - accuracy: 0.6975 - val_loss: 1.5580 - val_accuracy: 0.5615
# Epoch 14/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.7407 - accuracy: 0.7243 - val_loss: 1.7771 - val_accuracy: 0.5302
# Epoch 15/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.6957 - accuracy: 0.7377 - val_loss: 1.7155 - val_accuracy: 0.5570
# Epoch 16/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5634 - accuracy: 0.8030 - val_loss: 1.9445 - val_accuracy: 0.5302
# Epoch 17/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5513 - accuracy: 0.8008 - val_loss: 1.8143 - val_accuracy: 0.5660
# Epoch 18/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4725 - accuracy: 0.8281 - val_loss: 2.1160 - val_accuracy: 0.5481
# Epoch 19/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5227 - accuracy: 0.8114 - val_loss: 2.2197 - val_accuracy: 0.5235
# Epoch 20/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4163 - accuracy: 0.8482 - val_loss: 2.4982 - val_accuracy: 0.5235

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here
#
# From the above two graphs we can clearly observe that our model is **over fitting** since as you increase the epoches we can see the training accuracy is increasing but validation accuracy is staying down.

# %% [markdown]
# **Data Augmentation**

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(10, 20))
for images, labels in train_ds.take(1):
  for i in range(4):
    ax = plt.subplot(9, 2, 2*i+1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
    ax = plt.subplot(9, 2, 2*i+2)
    plt.imshow(data_augmentation(images[i]).numpy().astype("uint8"))
    plt.title("Augmented__"+class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model
# #### **Model M2**

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
### Your code goes here

num_classes = 9

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255,input_shape = (img_height,img_width,3)),
  data_augmentation, # New Data Augmentation  Layer
  tf.keras.layers.Conv2D(16, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(128, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Dropout(0.2), # New Droupout layer
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])
# Out:
# WARNING:tensorflow:Model was constructed with shape (180, 180, 3) for input KerasTensor(type_spec=TensorSpec(shape=(180, 180, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 180, 180, 3).

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_2 (Sequential)   (180, 180, 3)             0
#
#  conv2d_6 (Conv2D)           (None, 178, 178, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 89, 89, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 87, 87, 32)        4640
#
#  max_pooling2d_7 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 41, 41, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 20, 20, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 18, 18, 128)       73856
#
#  max_pooling2d_9 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 9, 9, 128)         0
#
#  flatten_2 (Flatten)         (None, 10368)             0
#
#  dense_6 (Dense)             (None, 128)               1327232
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  dense_8 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 1,442,345
# Trainable params: 1,442,345
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Model was constructed with shape (180, 180, 3) for input KerasTensor(type_spec=TensorSpec(shape=(180, 180, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 180, 180, 3).
# WARNING:tensorflow:Model was constructed with shape (180, 180, 3) for input KerasTensor(type_spec=TensorSpec(shape=(180, 180, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 180, 180, 3).
# 55/56 [============================>.] - ETA: 0s - loss: 2.0390 - accuracy: 0.2205
# WARNING:tensorflow:Model was constructed with shape (180, 180, 3) for input KerasTensor(type_spec=TensorSpec(shape=(180, 180, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 180, 180, 3).
# 56/56 [==============================] - 3s 29ms/step - loss: 2.0374 - accuracy: 0.2215 - val_loss: 1.8933 - val_accuracy: 0.3087
# Epoch 2/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.8851 - accuracy: 0.2907 - val_loss: 1.7429 - val_accuracy: 0.3266
# Epoch 3/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.6768 - accuracy: 0.3739 - val_loss: 1.6220 - val_accuracy: 0.3826
# Epoch 4/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.5456 - accuracy: 0.4375 - val_loss: 1.4679 - val_accuracy: 0.4743
# Epoch 5/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.4896 - accuracy: 0.4821 - val_loss: 1.5564 - val_accuracy: 0.4653
# Epoch 6/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.4203 - accuracy: 0.4967 - val_loss: 1.4564 - val_accuracy: 0.4676
# Epoch 7/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3974 - accuracy: 0.4961 - val_loss: 1.3891 - val_accuracy: 0.5145
# Epoch 8/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3594 - accuracy: 0.5067 - val_loss: 1.3690 - val_accuracy: 0.5123
# Epoch 9/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3574 - accuracy: 0.5000 - val_loss: 1.3717 - val_accuracy: 0.5280
# Epoch 10/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3396 - accuracy: 0.5273 - val_loss: 1.3799 - val_accuracy: 0.5101
# Epoch 11/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2836 - accuracy: 0.5391 - val_loss: 1.3619 - val_accuracy: 0.5190
# Epoch 12/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2855 - accuracy: 0.5352 - val_loss: 1.3257 - val_accuracy: 0.5324
# Epoch 13/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3214 - accuracy: 0.5301 - val_loss: 1.3429 - val_accuracy: 0.5302
# Epoch 14/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2707 - accuracy: 0.5497 - val_loss: 1.3054 - val_accuracy: 0.5526
# Epoch 15/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2450 - accuracy: 0.5430 - val_loss: 1.3656 - val_accuracy: 0.5011
# Epoch 16/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2582 - accuracy: 0.5569 - val_loss: 1.3952 - val_accuracy: 0.5235
# Epoch 17/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2197 - accuracy: 0.5619 - val_loss: 1.4063 - val_accuracy: 0.5056
# Epoch 18/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.2695 - accuracy: 0.5307 - val_loss: 1.2939 - val_accuracy: 0.5638
# Epoch 19/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2314 - accuracy: 0.5569 - val_loss: 1.3103 - val_accuracy: 0.5369
# Epoch 20/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2083 - accuracy: 0.5658 - val_loss: 1.2882 - val_accuracy: 0.5414

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# We can see now we removed Overfitting because training and validation accuracy is nearly same across all the epoches but main problem is accuracy is not good , so we will now deal with one common problem named class imabalance.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %% [markdown]
# ### Method 1

# %%
## Your code goes here.
path_list = [str(x).replace(str(data_dir_train)+"/","").split("/")[0] for x in data_dir_train.glob('*/*.jpg')]

# %%
from collections import Counter
count_data = dict(Counter(path_list))
count_data
# Out:
# {'squamous cell carcinoma': 181,
#  'nevus': 357,
#  'actinic keratosis': 114,
#  'vascular lesion': 139,
#  'seborrheic keratosis': 77,
#  'pigmented benign keratosis': 462,
#  'melanoma': 438,
#  'dermatofibroma': 95,
#  'basal cell carcinoma': 376}

# %%
plt.figure(figsize=(20, 8))
plt.bar(range(len(count_data)), list(count_data.values()), tick_label=list(count_data.keys()))

plt.show()

# %% [markdown]
# ### Method 2

# %%
path_list = [x for x in data_dir_train.glob(os.path.join('*', '*.jpg'))]
path_list[:5]
# Out:
# [PosixPath('gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/ISIC_0024923.jpg'),
#  PosixPath('gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/ISIC_0024946.jpg'),
#  PosixPath('gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/ISIC_0024710.jpg'),
#  PosixPath('gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/ISIC_0024925.jpg'),
#  PosixPath('gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/ISIC_0025029.jpg')]

# %%
lesion_list = [os.path.basename(os.path.dirname(y)) for y in data_dir_train.glob(os.path.join( '*','*.jpg'))]
lesion_list[:5]
# Out:
# ['squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma']

# %%
dataframe_dict = dict(zip(path_list, lesion_list))

# %%
original_df = pd.DataFrame(list(dataframe_dict.items()),columns = ['Path','Label'])
original_df.head(5)
# Out:
#                                                 Path                    Label
# 0  gdrive/MyDrive/Upgrad_deeplearning_Assignment/...  squamous cell carcinoma
# 1  gdrive/MyDrive/Upgrad_deeplearning_Assignment/...  squamous cell carcinoma
# 2  gdrive/MyDrive/Upgrad_deeplearning_Assignment/...  squamous cell carcinoma
# 3  gdrive/MyDrive/Upgrad_deeplearning_Assignment/...  squamous cell carcinoma
# 4  gdrive/MyDrive/Upgrad_deeplearning_Assignment/...  squamous cell carcinoma

# %%
original_df["Label"].value_counts()
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: Label, dtype: int64

# %%
count_data  = dict(original_df["Label"].value_counts())
plt.figure(figsize=(20, 8))
plt.bar(range(len(count_data)), list(count_data.values()), tick_label=list(count_data.keys()))

plt.show()

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - From the Graph we can clearly seee that the **seborrheic keratosis** class is having the least number of samples
# #### - Which classes dominate the data in terms proportionate number of samples?
# #### - **pigmented benign keratosis,melanoma,nevus,basal cell carcinoma** classes dominates the data in terms proportionate number of samples.

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.7/dist-packages (0.2.10)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset=str(data_dir_train)
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(pathlib.Path(path_to_training_dataset +"/"+ i))
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FF2E0058410>: 100%|██████████| 500/500 [00:19<00:00, 26.06 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF2F29E5D50>: 100%|██████████| 500/500 [00:19<00:00, 26.10 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF2E0082110>: 100%|██████████| 500/500 [00:18<00:00, 26.58 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FF2F2767F90>: 100%|██████████| 500/500 [01:37<00:00,  5.11 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1011x713 at 0x7FF2E0082290>: 100%|██████████| 500/500 [01:21<00:00,  6.13 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF2F3843F50>: 100%|██████████| 500/500 [00:18<00:00, 26.83 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FF2F2A43650>: 100%|██████████| 500/500 [00:41<00:00, 12.06 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FF2E00D8C90>: 100%|██████████| 500/500 [00:19<00:00, 26.28 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF2E0160AD0>: 100%|██████████| 500/500 [00:18<00:00, 26.86 Samples/s]

# %%
path_to_training_dataset=str(data_dir_train)
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(pathlib.Path(path_to_training_dataset +"/"+ i))
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.shear(probability=0.5,max_shear_left=10,max_shear_right=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F98DA522E50>: 100%|██████████| 500/500 [00:25<00:00, 19.44 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F98DBD00290>: 100%|██████████| 500/500 [00:25<00:00, 19.82 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F98DA63BCD0>: 100%|██████████| 500/500 [00:25<00:00, 19.88 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F98DD3D2110>: 100%|██████████| 500/500 [02:17<00:00,  3.65 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=919x802 at 0x7F98F2040D50>: 100%|██████████| 500/500 [02:05<00:00,  3.97 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F98DA4D9390>: 100%|██████████| 500/500 [00:25<00:00, 19.55 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F98DD473CD0>: 100%|██████████| 500/500 [01:00<00:00,  8.28 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F98DA38A150>: 100%|██████████| 500/500 [00:24<00:00, 20.59 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to gdrive/MyDrive/Upgrad_deeplearning_Assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F98DC757150>: 100%|██████████| 500/500 [00:25<00:00, 19.73 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in data_dir_train.glob(os.path.join('*','output', '*.jpg'))]
#path_list_new

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in data_dir_train.glob(os.path.join( '*','output', '*.jpg'))]
lesion_list_new[:5]
# Out:
# ['squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma',
#  'squamous cell carcinoma']

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)

# %%
count_data  = dict(new_df["Label"].value_counts())
plt.figure(figsize=(20, 5))
plt.bar(range(len(count_data)), list(count_data.values()), tick_label=list(count_data.keys()))

plt.show()

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
#data_dir_train="path to directory with training data + data created using augmentor"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset ="training", ## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)
# ## **Model M3**

# %%
## your code goes here
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
### Your code goes here

num_classes = 9

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255,input_shape = (img_height,img_width,3)),
  tf.keras.layers.Conv2D(16, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(128, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Dropout(0.2), # New Droupout layer
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_18 (Conv2D)          (None, 178, 178, 16)      448
#
#  max_pooling2d_18 (MaxPoolin  (None, 89, 89, 16)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 87, 87, 32)        4640
#
#  max_pooling2d_19 (MaxPoolin  (None, 43, 43, 32)       0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 41, 41, 64)        18496
#
#  max_pooling2d_20 (MaxPoolin  (None, 20, 20, 64)       0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 18, 18, 128)       73856
#
#  max_pooling2d_21 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 9, 9, 128)         0
#
#  flatten_5 (Flatten)         (None, 10368)             0
#
#  dense_15 (Dense)            (None, 128)               1327232
#
#  dense_16 (Dense)            (None, 128)               16512
#
#  dense_17 (Dense)            (None, 9)                 1161
#
# =================================================================
# Total params: 1,442,345
# Trainable params: 1,442,345
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 34s 191ms/step - loss: 2.0570 - accuracy: 0.1975 - val_loss: 1.8121 - val_accuracy: 0.2732
# Epoch 2/50
# 169/169 [==============================] - 32s 182ms/step - loss: 1.6402 - accuracy: 0.3609 - val_loss: 1.4352 - val_accuracy: 0.4417
# Epoch 3/50
# 169/169 [==============================] - 31s 180ms/step - loss: 1.4576 - accuracy: 0.4382 - val_loss: 1.3772 - val_accuracy: 0.4536
# Epoch 4/50
# 169/169 [==============================] - 30s 174ms/step - loss: 1.3628 - accuracy: 0.4751 - val_loss: 1.3617 - val_accuracy: 0.4714
# Epoch 5/50
# 169/169 [==============================] - 30s 174ms/step - loss: 1.2535 - accuracy: 0.5206 - val_loss: 1.2359 - val_accuracy: 0.5167
# Epoch 6/50
# 169/169 [==============================] - 30s 175ms/step - loss: 1.1674 - accuracy: 0.5506 - val_loss: 1.3620 - val_accuracy: 0.5115
# Epoch 7/50
# 169/169 [==============================] - 31s 176ms/step - loss: 1.1102 - accuracy: 0.5805 - val_loss: 1.0466 - val_accuracy: 0.6058
# Epoch 8/50
# 169/169 [==============================] - 30s 175ms/step - loss: 1.0044 - accuracy: 0.6176 - val_loss: 1.0311 - val_accuracy: 0.6162
# Epoch 9/50
# 169/169 [==============================] - 31s 175ms/step - loss: 0.8403 - accuracy: 0.6849 - val_loss: 0.9967 - val_accuracy: 0.6310
# Epoch 10/50
# 169/169 [==============================] - 30s 175ms/step - loss: 0.7145 - accuracy: 0.7352 - val_loss: 0.9510 - val_accuracy: 0.6778
# Epoch 11/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.6634 - accuracy: 0.7541 - val_loss: 0.8221 - val_accuracy: 0.7127
# Epoch 12/50
# 169/169 [==============================] - 31s 176ms/step - loss: 0.5683 - accuracy: 0.7876 - val_loss: 0.7567 - val_accuracy: 0.7491
# Epoch 13/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.5419 - accuracy: 0.7986 - val_loss: 0.7310 - val_accuracy: 0.7409
# Epoch 14/50
# 169/169 [==============================] - 31s 176ms/step - loss: 0.4347 - accuracy: 0.8361 - val_loss: 0.6990 - val_accuracy: 0.7795
# Epoch 15/50
# 169/169 [==============================] - 31s 176ms/step - loss: 0.3625 - accuracy: 0.8615 - val_loss: 0.6807 - val_accuracy: 0.7884
# Epoch 16/50
# 169/169 [==============================] - 31s 175ms/step - loss: 0.3549 - accuracy: 0.8672 - val_loss: 0.7675 - val_accuracy: 0.7617
# Epoch 17/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.3341 - accuracy: 0.8718 - val_loss: 0.8785 - val_accuracy: 0.7446
# Epoch 18/50
# 169/169 [==============================] - 30s 173ms/step - loss: 0.3792 - accuracy: 0.8576 - val_loss: 0.7750 - val_accuracy: 0.7580
# Epoch 19/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.2720 - accuracy: 0.8948 - val_loss: 0.5622 - val_accuracy: 0.8255
# Epoch 20/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.2529 - accuracy: 0.8999 - val_loss: 0.6964 - val_accuracy: 0.8226
# Epoch 21/50
# 169/169 [==============================] - 30s 173ms/step - loss: 0.2926 - accuracy: 0.8885 - val_loss: 0.6260 - val_accuracy: 0.8122
# Epoch 22/50
# 169/169 [==============================] - 30s 173ms/step - loss: 0.2080 - accuracy: 0.9154 - val_loss: 0.6625 - val_accuracy: 0.8278
# Epoch 23/50
# 169/169 [==============================] - 30s 173ms/step - loss: 0.2528 - accuracy: 0.9067 - val_loss: 0.7397 - val_accuracy: 0.7906
# Epoch 24/50
# 169/169 [==============================] - 31s 176ms/step - loss: 0.2024 - accuracy: 0.9217 - val_loss: 0.6638 - val_accuracy: 0.8344
# Epoch 25/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1747 - accuracy: 0.9308 - val_loss: 0.7369 - val_accuracy: 0.8070
# Epoch 26/50
# 169/169 [==============================] - 30s 172ms/step - loss: 0.2642 - accuracy: 0.9065 - val_loss: 0.6150 - val_accuracy: 0.8137
# Epoch 27/50
# 169/169 [==============================] - 30s 175ms/step - loss: 0.2164 - accuracy: 0.9175 - val_loss: 0.6586 - val_accuracy: 0.8300
# Epoch 28/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1847 - accuracy: 0.9258 - val_loss: 0.6830 - val_accuracy: 0.8226
# Epoch 29/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1561 - accuracy: 0.9362 - val_loss: 0.6925 - val_accuracy: 0.8434
# Epoch 30/50
# 169/169 [==============================] - 30s 173ms/step - loss: 0.1386 - accuracy: 0.9425 - val_loss: 0.6320 - val_accuracy: 0.8537
# Epoch 31/50
# 169/169 [==============================] - 31s 177ms/step - loss: 0.1533 - accuracy: 0.9395 - val_loss: 0.8244 - val_accuracy: 0.8070
# Epoch 32/50
# 169/169 [==============================] - 30s 173ms/step - loss: 0.1857 - accuracy: 0.9275 - val_loss: 0.6464 - val_accuracy: 0.8441
# Epoch 33/50
# 169/169 [==============================] - 30s 172ms/step - loss: 0.1788 - accuracy: 0.9267 - val_loss: 0.7154 - val_accuracy: 0.8248
# Epoch 34/50
# 169/169 [==============================] - 31s 176ms/step - loss: 0.1807 - accuracy: 0.9312 - val_loss: 0.7686 - val_accuracy: 0.8166
# Epoch 35/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1591 - accuracy: 0.9382 - val_loss: 0.7415 - val_accuracy: 0.8330
# Epoch 36/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1843 - accuracy: 0.9279 - val_loss: 0.8573 - val_accuracy: 0.8085
# Epoch 37/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1683 - accuracy: 0.9369 - val_loss: 0.8498 - val_accuracy: 0.8174
# Epoch 38/50
# 169/169 [==============================] - 30s 173ms/step - loss: 0.1489 - accuracy: 0.9394 - val_loss: 0.8351 - val_accuracy: 0.8203
# Epoch 39/50
# 169/169 [==============================] - 30s 173ms/step - loss: 0.1185 - accuracy: 0.9499 - val_loss: 0.7648 - val_accuracy: 0.8374
# Epoch 40/50
# 169/169 [==============================] - 31s 175ms/step - loss: 0.1774 - accuracy: 0.9336 - val_loss: 0.8007 - val_accuracy: 0.8114
# Epoch 41/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1446 - accuracy: 0.9427 - val_loss: 0.7926 - val_accuracy: 0.8166
# Epoch 42/50
# 169/169 [==============================] - 30s 175ms/step - loss: 0.1359 - accuracy: 0.9466 - val_loss: 0.7349 - val_accuracy: 0.8441
# Epoch 43/50
# 169/169 [==============================] - 30s 173ms/step - loss: 0.1264 - accuracy: 0.9477 - val_loss: 0.7289 - val_accuracy: 0.8411
# Epoch 44/50
# 169/169 [==============================] - 31s 175ms/step - loss: 0.1273 - accuracy: 0.9462 - val_loss: 0.7364 - val_accuracy: 0.8367
# Epoch 45/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1152 - accuracy: 0.9536 - val_loss: 0.7796 - val_accuracy: 0.8508
# Epoch 46/50
# 169/169 [==============================] - 30s 175ms/step - loss: 0.1449 - accuracy: 0.9420 - val_loss: 0.8980 - val_accuracy: 0.8293
# Epoch 47/50
# 169/169 [==============================] - 30s 175ms/step - loss: 0.1338 - accuracy: 0.9483 - val_loss: 0.9084 - val_accuracy: 0.8404
# Epoch 48/50
# 169/169 [==============================] - 30s 175ms/step - loss: 0.2485 - accuracy: 0.9210 - val_loss: 0.8080 - val_accuracy: 0.8218
# Epoch 49/50
# 169/169 [==============================] - 30s 174ms/step - loss: 0.1215 - accuracy: 0.9510 - val_loss: 0.8725 - val_accuracy: 0.8211
# Epoch 50/50
# 169/169 [==============================] - 31s 175ms/step - loss: 0.1366 - accuracy: 0.9451 - val_loss: 0.7972 - val_accuracy: 0.8233

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
# #### Ans : Class rebalance helped so much that our accuracy is increased from 60 to 80 using the class rebalance technique . From above graph we can also observe that at 20 epoches our model is stabilized, beyong 20 epoches our model is overfitting.
